# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\python311.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0', '', 'C:\\Users\\alyss\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages', 'C:\\Users\\alyss\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\win32', 'C:\\Users\\alyss\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\win32\\lib', 'C:\\Users\\alyss\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.1
# ...

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from dynamic import Submarine, Mission, ClosedLoop # IMPORTING THE NECESSARY FUNCTIONS FROM dynamic
from control import PDController # IMPORTING THE NECESSARY FUNCTION FROM control

sub = Submarine()
# Instantiate your controller (depending on your implementation)
kp = 0.10 # Choosing the proportional gain
kd = 0.6 # Choosing the derivative gain
controller = PDController(kp=kp, kd=kd)

closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv(r"C:\Users\alyss\Documents\B1-PROJECT-1\b1-coding-practical-mt24\uuv_mission\mission.csv") # This is the relative path of the mission file.

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
